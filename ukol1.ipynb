# %%
import pandas

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
elections = pandas.read_csv("1976-2020-president.csv")  #nacteni dat
elections
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
elections["Rank"] = elections.groupby(["year", "state"])["candidatevotes"].rank(method = "min", ascending=False) #vytvoreni sloupce "Rank" a serazeni podle roku a statu,prirazeni hodnoty rank
elections.tail(15)
# Out:
#       year      state state_po  state_fips  state_cen  state_ic        office  \
# 4272  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4273  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4274  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4275  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4276  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4277  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4278  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4279  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4280  2020    WYOMING       WY          56         83        68  US PRESIDENT
# 4281  2020    WYOMING       WY          56         83        68  US PRESIDENT
# 4282  2020    WYOMING       WY          56         83        68  US PRESIDENT
# ...

# %%
elections_winners = elections[elections["Rank"] == 1.0] #vyselektovani vitezu
elections_winners
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        ALABAMA       AL           1         63        41
# 7     1976         ALASKA       AK           2         94        81
# 11    1976        ARIZONA       AZ           4         86        61
# 19    1976       ARKANSAS       AR           5         71        42
# 23    1976     CALIFORNIA       CA           6         93        71
# ...    ...            ...      ...         ...        ...       ...
# 4252  2020       VIRGINIA       VA          51         54        40
# 4256  2020     WASHINGTON       WA          53         91        73
# 4264  2020  WEST VIRGINIA       WV          54         55        56
# 4267  2020      WISCONSIN       WI          55         35        25
# 4281  2020        WYOMING       WY          56         83        68
#
#             office            candidate party_detailed writein  \
# 0     US PRESIDENT        CARTER, JIMMY       DEMOCRAT   False
# ...

# %%
elections_winners_sorted = elections_winners.sort_values(["state", "year"]) #serazeni podle roku a statu
elections_winners_sorted["previous_winner_party"]= elections_winners_sorted.groupby(["state"])["party_detailed"].shift(1)   #vytvoreni sloupce "previous winner party" a prirazeni hodnoty
elections_winners_sorted.head(15)
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 332   1980  ALABAMA       AL           1         63        41  US PRESIDENT
# 696   1984  ALABAMA       AL           1         63        41  US PRESIDENT
# 1019  1988  ALABAMA       AL           1         63        41  US PRESIDENT
# 1304  1992  ALABAMA       AL           1         63        41  US PRESIDENT
# 1674  1996  ALABAMA       AL           1         63        41  US PRESIDENT
# 2042  2000  ALABAMA       AL           1         63        41  US PRESIDENT
# 2411  2004  ALABAMA       AL           1         63        41  US PRESIDENT
# 2728  2008  ALABAMA       AL           1         63        41  US PRESIDENT
# 3079  2012  ALABAMA       AL           1         63        41  US PRESIDENT
# 3395  2016  ALABAMA       AL           1         63        41  US PRESIDENT
# ...

# %%
elections_winners_sorted["change"] = numpy.where(elections_winners_sorted["previous_winner_party"] != elections_winners_sorted["party_simplified"], int(1),int(0))  #vytvoreni sloupce "change" a zadani podminky pro jeho obsah
elections_winners_sorted2 = elections_winners_sorted.loc[elections_winners_sorted["year"]!=1976]    #odstraneni roku 1976
elections_winners_sorted2.tail(15)
# Out:
#       year      state state_po  state_fips  state_cen  state_ic        office  \
# 3063  2008  WISCONSIN       WI          55         35        25  US PRESIDENT
# 3383  2012  WISCONSIN       WI          55         35        25  US PRESIDENT
# 3723  2016  WISCONSIN       WI          55         35        25  US PRESIDENT
# 4267  2020  WISCONSIN       WI          55         35        25  US PRESIDENT
# 692   1980    WYOMING       WY          56         83        68  US PRESIDENT
# 1016  1984    WYOMING       WY          56         83        68  US PRESIDENT
# 1300  1988    WYOMING       WY          56         83        68  US PRESIDENT
# 1669  1992    WYOMING       WY          56         83        68  US PRESIDENT
# 2037  1996    WYOMING       WY          56         83        68  US PRESIDENT
# 2405  2000    WYOMING       WY          56         83        68  US PRESIDENT
# 2722  2004    WYOMING       WY          56         83        68  US PRESIDENT
# ...

# %%
data_pivot = elections_winners_sorted2.groupby(["state"])["change"].sum()   #serazeni dat a pocet hodnot sloupce "change"
data_pivot = pandas.DataFrame(data_pivot)
data_pivot = data_pivot.sort_values("change", ascending=False)
data_pivot.head(10)
# Out:
#                change
# state
# FLORIDA             5
# OHIO                5
# IOWA                4
# WISCONSIN           4
# PENNSYLVANIA        4
# GEORGIA             4
# MISSOURI            3
# NEW MEXICO          3
# NEW HAMPSHIRE       3
# NEVADA              3

# %%
data = data_pivot.iloc[:10] #vytvoreni grafu pro 10 statu
data.plot(kind="bar")
# Out:
# <Axes: xlabel='state'>

# %%
elections_winners_two = elections[elections["Rank"] < 2.1] #vygenerovani tabulky s vitezi voleb a druhymi v poradi
elections_winners_two
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        ALABAMA       AL           1         63        41
# 1     1976        ALABAMA       AL           1         63        41
# 7     1976         ALASKA       AK           2         94        81
# 8     1976         ALASKA       AK           2         94        81
# 11    1976        ARIZONA       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 4264  2020  WEST VIRGINIA       WV          54         55        56
# 4267  2020      WISCONSIN       WI          55         35        25
# 4268  2020      WISCONSIN       WI          55         35        25
# 4280  2020        WYOMING       WY          56         83        68
# 4281  2020        WYOMING       WY          56         83        68
#
#             office            candidate party_detailed writein  \
# 0     US PRESIDENT        CARTER, JIMMY       DEMOCRAT   False
# ...

# %%
elections_winners_votes = elections_winners_two.sort_values(["year", "state", "candidatevotes"], ascending= True)   #serazeni hodnot podle roku,statu a poctu hlasu
elections_winners_votes["margin"] = elections_winners_votes.groupby(["year", "state"])["candidatevotes"].shift(1)   #vytvoreni sloupce "margin" a dosazeni hodnot
elections_winners_votes["margin"] = abs(elections_winners_votes["candidatevotes"] - elections_winners_votes["margin"])  #absolutni hodnota vysledku odecteni hlasu viteze a druheho
elections_winners_margin = elections_winners_votes[elections_winners_votes["Rank"] == 1]    #vyselektovani pouze vitezove a o kolik hlasu vyhrali
elections_winners_margin.head()
# Out:
#     year       state state_po  state_fips  state_cen  state_ic        office  \
# 0   1976     ALABAMA       AL           1         63        41  US PRESIDENT
# 7   1976      ALASKA       AK           2         94        81  US PRESIDENT
# 11  1976     ARIZONA       AZ           4         86        61  US PRESIDENT
# 19  1976    ARKANSAS       AR           5         71        42  US PRESIDENT
# 23  1976  CALIFORNIA       CA           6         93        71  US PRESIDENT
#
#         candidate party_detailed writein  candidatevotes  totalvotes  \
# 0   CARTER, JIMMY       DEMOCRAT   False          659170     1182850
# 7    FORD, GERALD     REPUBLICAN   False           71555      123574
# 11   FORD, GERALD     REPUBLICAN   False          418642      742719
# 19  CARTER, JIMMY       DEMOCRAT   False          498604      767535
# 23   FORD, GERALD     REPUBLICAN   False         3882244     7803770
#
#      version  notes party_simplified  Rank    margin
# ...

# %%
elections_winners_margin["relative_margin"] = elections_winners_margin["margin"]/elections_winners_margin["totalvotes"] #vytvoreni sloupce pro relativni hodnotu 
elections_winners_margin.head()
# Out:
# C:\Users\dana.dekanova\AppData\Local\Temp\ipykernel_22768\3002369348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections_winners_margin["relative_margin"] = elections_winners_margin["margin"]/elections_winners_margin["totalvotes"]
#     year       state state_po  state_fips  state_cen  state_ic        office  \
# 0   1976     ALABAMA       AL           1         63        41  US PRESIDENT
# 7   1976      ALASKA       AK           2         94        81  US PRESIDENT
# 11  1976     ARIZONA       AZ           4         86        61  US PRESIDENT
# 19  1976    ARKANSAS       AR           5         71        42  US PRESIDENT
# 23  1976  CALIFORNIA       CA           6         93        71  US PRESIDENT
#
# ...

# %%
elections_winners_relative_margin = elections_winners_margin.sort_values(["relative_margin"], ascending=True)
elections_winners_relative_margin.head()
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 2106  2000        FLORIDA       FL          12         59        43
# 2266  2000     NEW MEXICO       NM          35         85        66
# 2907  2008       MISSOURI       MO          29         43        34
# 479   1980  MASSACHUSETTS       MA          25         14         3
# 241   1976         OREGON       OR          41         92        72
#
#             office        candidate party_detailed writein  candidatevotes  \
# 2106  US PRESIDENT  BUSH, GEORGE W.     REPUBLICAN   False         2912790
# 2266  US PRESIDENT         GORE, AL       DEMOCRAT   False          286783
# 2907  US PRESIDENT     MCCAIN, JOHN     REPUBLICAN   False         1445814
# 479   US PRESIDENT   REAGAN, RONALD     REPUBLICAN   False         1057631
# 241   US PRESIDENT     FORD, GERALD     REPUBLICAN   False          492120
#
#       totalvotes   version  notes party_simplified  Rank  margin  \
# ...

# %%
def swing(i):   #definice vlastni funkce pro prirazeni hodnot do sloupce "swing"
    if i["change"] == 1:
        if i["previous_winner_party"] == "DEMOCRAT":
            return "to Rep."
        else:
            return "to Dem."
    else:
        return "no swing"
    
elections_winners_sorted2["swing"] = elections_winners_sorted2.apply(swing,axis =1) #vytvoreni sloupce a pouziti funkce
elections_winners_sorted2.head()
# Out:
# C:\Users\dana.dekanova\AppData\Local\Temp\ipykernel_22768\4118749670.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections_winners_sorted2["swing"] = elections_winners_sorted2.apply(swing,axis =1)
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 332   1980  ALABAMA       AL           1         63        41  US PRESIDENT
# 696   1984  ALABAMA       AL           1         63        41  US PRESIDENT
# 1019  1988  ALABAMA       AL           1         63        41  US PRESIDENT
# 1304  1992  ALABAMA       AL           1         63        41  US PRESIDENT
# 1674  1996  ALABAMA       AL           1         63        41  US PRESIDENT
#
# ...

# %%
elections_pivot = pandas.pivot_table(data=elections_winners_sorted2,values="state", index ="year",columns = "swing", aggfunc="count")   #vytvoreni kontingencni tabulky - nektere roky mi tam o jedno nesedi s porovnanim dat z napovedy, ale nemohla jsem najit, kde je chyba
elections_pivot
# Out:
# swing  no swing  to Dem.  to Rep.
# year
# 1980       35.0      NaN     16.0
# 1984       45.0      NaN      6.0
# 1988       42.0      9.0      NaN
# 1992       29.0     22.0      NaN
# 1996       46.0      2.0      3.0
# 2000       40.0      NaN     11.0
# 2004       47.0      2.0      2.0
# 2008       41.0     10.0      NaN
# 2012       49.0      NaN      2.0
# 2016       44.0      1.0      6.0
# 2020       46.0      5.0      NaN
